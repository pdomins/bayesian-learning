# %%
import sys
sys.path.append('../')

# %%
import numpy as np
import pandas as pd
import math
from data_split import k_fold_split, k_fold_n_splits

# %%
df = pd.read_excel("../data/2-PreferenciasBritanicos(TP1).xlsx")
df
# Out:
#     scones  cerveza  wiskey  avena  futbol Nacionalidad
# 0        0        0       1      1       1            I
# 1        1        0       1      1       0            I
# 2        1        1       0      0       1            I
# 3        1        1       0      0       0            I
# 4        0        1       0      0       1            I
# 5        0        0       0      1       0            I
# 6        1        0       0      1       1            E
# 7        1        1       0      0       1            E
# 8        1        1       1      1       0            E
# 9        1        1       0      1       0            E
# 10       1        1       0      1       1            E
# 11       1        0       1      1       0            E
# 12       1        0       1      0       0            E

# %%
random_generator = np.random.default_rng(seed=42)

# %%
k = 3

# %%
test_size = df.shape[0] / k
(test_size * (k-1), test_size)
# Out:
# (8.666666666666666, 4.333333333333333)

# %%
train_df, test_df = k_fold_split(df, k, random_generator)

# %%
train_df
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 8       1       1      1     1      0            E
# 11      1       0      1     1      0            E
# 5       0       0      0     1      0            I
# 10      1       1      0     1      1            E
# 9       1       1      0     1      0            E
# 3       1       1      0     0      0            I
# 6       1       0      0     1      1            E
# 1       1       0      1     1      0            I
# 7       1       1      0     0      1            E

# %%
test_df
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 0       0       0      1     1      1            I
# 2       1       1      0     0      1            I
# 4       0       1      0     0      1            I
# 12      1       0      1     0      0            E

# %%
n = 3

# %%
[(train_df_1, test_df_1), (train_df_2, test_df_2), (train_df_3, test_df_3)] = k_fold_n_splits(df, k, n, random_generator)

# %%
train_df_1
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 7       1       1      0     0      1            E
# 9       1       1      0     1      0            E
# 2       1       1      0     0      1            I
# 1       1       0      1     1      0            I
# 10      1       1      0     1      1            E
# 8       1       1      1     1      0            E
# 0       0       0      1     1      1            I
# 12      1       0      1     0      0            E
# 3       1       1      0     0      0            I

# %%
train_df_2
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 7       1       1      0     0      1            E
# 9       1       1      0     1      0            E
# 2       1       1      0     0      1            I
# 1       1       0      1     1      0            I
# 10      1       1      0     1      1            E
# 11      1       0      1     1      0            E
# 4       0       1      0     0      1            I
# 5       0       0      0     1      0            I
# 6       1       0      0     1      1            E

# %%
train_df_3
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 11      1       0      1     1      0            E
# 4       0       1      0     0      1            I
# 5       0       0      0     1      0            I
# 6       1       0      0     1      1            E
# 8       1       1      1     1      0            E
# 0       0       0      1     1      1            I
# 12      1       0      1     0      0            E
# 3       1       1      0     0      0            I

# %%
test_df_1
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 11      1       0      1     1      0            E
# 4       0       1      0     0      1            I
# 5       0       0      0     1      0            I
# 6       1       0      0     1      1            E

# %%
test_df_2
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 8       1       1      1     1      0            E
# 0       0       0      1     1      1            I
# 12      1       0      1     0      0            E
# 3       1       1      0     0      0            I

# %%
test_df_3
# Out:
#    scones cerveza wiskey avena futbol Nacionalidad
# 7       1       1      0     0      1            E
# 9       1       1      0     1      0            E
# 2       1       1      0     0      1            I
# 1       1       0      1     1      0            I
# 10      1       1      0     1      1            E
